# %%
# Example job postings
jobs = [
    """ Senior Software Engineer - Team Lead
    About the job
Job Description



We're a cutting-edge startup revolutionising how people work with and exchange data. If you're passionate about solving complex problems and pushing technological boundaries, this is your chance to build a groundbreaking system from scratch.
We're seeking a highly skilled Senior System Developer with leadership experience to guide our team. You'll play a vital role in developing our next-generation data product, utilising your expertise in software development. You will also need to show you eagerness to independently learn Rust.


As a Team Lead, you will:

Drive technical excellence within your team, providing mentorship and guidance to talented Rust developers.
Own the design and execution of key components within our cutting-edge product.
Collaborate closely with cross-functional teams to deliver a seamless user experience.


Qualifications

Computer science degree or equivalent.
5+ years of experience in system programming languages (C, C++, Go, Rust is a major plus, Java/Scala).
Proven ability to learn new technologies quickly, with strong foundational knowledge to rapidly master Rust.
Experience leading and mentoring a small team of developers.
Ability to work on-site in Tunis-Belvedere at least 3 days a week.
Excellent English communication skills (written and verbal).


What sets you apart:

A collaborative mindset, embracing diverse perspectives and approaches.
A passion for innovation and a drive to continuously improve.
The ability to take calculated risks, iterate quickly, and learn from failures.
Strong communication skills and ability to thrive in a dynamic, ambitious environment.


What we offer:

The opportunity to shape the future of data technology.
A fast-paced environment where your growth potential is limitless.
Competitive salary and a comprehensive benefits package.
    """,


    """ 3 Senior Data Scientist
    About the job
Role Description
This is a full-time hybrid role for a Senior Data Scientist at FIND Solutions. As a Senior Data Scientist, you will be responsible for performing day-to-day tasks such as data analytics, data analysis, data visualization, and applying statistical methods to large datasets. This role is based in Rabat and offers flexibility for some remote work.
Qualifications
Data Science, Statistics, and Data Analytics skills
Data Visualization and Data Analysis skills
Experience in applying statistical methods to large datasets
Strong problem-solving and critical-thinking abilities
Excellent programming skills in languages such as Python,SQL, and Cloud(GCP or AWS)
Experience with machine learning algorithms and techniques
Knowledge of data cleaning and preprocessing techniques
Strong communication and presentation skills
Ability to work effectively in a team and independently
Master's or Ph.D. in Data Science, Statistics, or related field

    """,


    """ 1 Senior Data Scientist Sigma Software Group
    About the job
Unleash your ambition as a Senior Data Scientist! We are looking for a professional who not only has impressive experience in data science but is also ready to take on a driver role, contributing to our Data Competency Center within Sigma Software. The role will involve Solution assessment, pre-sales activities under supervision, architecture design composition, and more.
PROJECT

We are a team of 160+ professionals. We are very different, but a few things make us a true team: a genuine passion for our work, friendliness, and inexhaustible optimism, no matter what.
We use Agile with technical excellence in place and Kanban approaches to do great work and make customers happy. Our goal is to offer our clients the best expertise in different domains to bring value to their business and become the best tech partner.
REQUIREMENTS

Expertise in machine learning algorithms, including linear regression, clustering, classification, and recommendation systems
Proven ability to create clear, concise, and compelling visualizations using tools like ggplot2, matplotlib, or plotly, Power BI, Tableau, and Qlik
Conceptual understanding of data analysis fundamentals, encompassing ETL, data warehousing, and unstructured data
A comprehensive grasp of deep learning fundamentals, including activation functions, backpropagation, CNNs, Transformers, transfer learning, and generative models Expertise in evaluating and selecting the most appropriate deep learning model for a given task, including assessing model performance metrics, identifying potential biases, and comparing different model architectures
PERSONAL PROFILE

Analytical and Problem-Solving Skills:
Demonstrated problem-solving and analytical thinking skills, with a proven track record of applying these skills to real-world challenges to identify problems, gather relevant data, and develop creative solutions
Continuous learning mindset, ensuring you stay up-to-date with the latest advancements in deep learning and adapt skills accordingly
Actively participate in the evaluation of new tools for analytical data engineering or data science
RESPONSIBILITIES

Work closely with the client (PO) as well as other Team Leads to clarify the tech requirements and expectations
 Translate complex business problems into actionable data-driven questions or hypotheses. This will involve working with stakeholders to understand the underlying issues and defining the specific questions that need to be answered through data analysis
 Collect data from various sources, identify and address data quality issues, and convert the data into a format suitable for analysis and modeling. This will involve using data wrangling techniques, data cleaning tools, and data quality checks
 Apply statistical methods, data visualization techniques, and machine learning algorithms to uncover hidden patterns, trends, and anomalies within the data. These insights will inform the development of effective models and solutions
Select and apply appropriate machine learning or statistical models to address specific business problems. This involves understanding the problem at hand, choosing the right algorithms, training the models on the prepared data, and evaluating their performance
 Work with engineers to integrate trained models into production environments, ensuring that they can be used to make real-time predictions or decisions. This involves deploying the models, monitoring their performance, and maintaining them over time
Effectively communicate complex data-driven insights and recommendations to stakeholders in a clear, concise, and actionable manner. This involves using storytelling techniques, visualizations, and presentations to effectively convey the findings and their implications for business decisions
Continuously research and stay up-to-date with the latest advancements in data science, including new algorithms, techniques, and tools, and explore emerging technologies and methodologies. This involves attending conferences, reading research papers, and experimenting with new approaches
Suggest and contribute to training and improvement plans regarding analytical data engineering skills, standards, and processes
    """,


    """ 10 ML Engineer / Data Scientist
    About the job
Job Description

We are looking for a Machine Learning Engineer / Data Scientist that will help us build the intelligence behind our systems. You will apply the latest machine learning algorithms to improve the lives of people and to help doctors in their diagnoses. In this role, you will have a strong impact on the company's success.

About The Role

You will be part of our engineering team consisting of machine learning, backend, Android, and iOS engineers.
You will have the chance to work on top of the biggest diabetes database in the world, with over 3 billion data points.
You will play a role in every part of our machine learning lifecycle: from the initial research to the production-level implementation, from discussing long-term goals, to making post-release micro-improvements.
You will navigate yourself quickly through the sea of machine learning literature, keeping our concrete goals as a compass. You will decide the best model for every problem and will be keen to implement that in practice (Python). You are able to explain your choices at any level of detail, from discussing the activation function of your neural network convolutional layer to the most accessible explanation of your goals and results.
You will take ownership of core projects of our company and we can rely on you to drive them forward proactively.

Qualifications

You have an exploratory mindset with a bias towards action.
You have a strong analytical and quantitative background.
You have experience with researching, data science modeling, or engineering in the aforementioned domains.
You have experience with machine learning, classification, regression, categorical and numeric.
You have experience with time series analysis.
You have experience with neural networks (different models and different applications).
You can take a project from idea to experiment, to prototype, to implementation.
You have experience with the technical tools for analysis, especially in Python
You have experience with SQL.

About Glooko

There are over 537 million people in the world with diabetes.

Glooko, a connected care platform for diabetes, helps patients and their care team more efficiently manage their condition between appointments. The digital health platform seamlessly unifies data from many of the leading diabetes and health monitoring devices to deliver insights that improve personal and clinical decision support. The free Glooko Mobile and Web App enables patients to easily track and proactively manage all aspects of their diabetes care.

At Glooko, our proven technologies for diabetes and related chronic conditions make lives better by revolutionizing the connection between patients and providers, driving patient engagement and adherence via digital therapeutics, and accelerating the speed of clinical trials.

Launched in 2010, Glooko is funded and managed by visionary technologists and leaders in healthcare. Glooko is globally deployed in over 30 countries and 8,000+ clinical locations.

     """,


    """ 18   Senior Data Scientist Sky Ledge · Istanbul
    About the job
About Sky Ledge

At Sky Ledge, we are revolutionising the SaaS landscape by developing an operational insights platform that enables businesses to achieve visibility and control of their operations and their assets.



Our primary focus is to deliver solutions that address the unique and complex challenges faced by large-scale businesses in West Africa. This includes critical issues like fuel theft, driver performance, route optimization, asset utilisation, operational automation and more.


Our mission is clear and crucial: we bring clarity and control to the intricate world of fleet operations.


Position Overview

We at Sky Ledge are on the lookout for a Senior Data Scientist to enhance our team. The successful candidate will play a pivotal role in analysing telematics and operational data to enhance and innovate performance metrics for vehicles, assets, and drivers.



This position goes beyond data analysis; it's about seeing beyond the data to reveal the truths of real-world operations.


Responsibilities

Analyse vehicle telematics data to identify insights, resolve issues and inconsistencies, and ensure the data is clean and ready to use.
Devise and implement sophisticated analytical models to scrutinise vehicle, asset, and driver performance.
Engage with cross-functional teams to decode operational challenges, transforming them into data-centric solutions.
A commitment to evolving performance metrics by combining telematics and asset data with actual operational conditions.
Sharing complex ideas and findings verbally and visually in an understandable manner with nontechnical stakeholders
Ensure codes for data pipeline and model development are efficient and well-documented.
Design and propose solutions with a focus on ethical and responsible usage of the data.
Collect, prepare and process data relevant to analysis and modelling tasks ensuring high data quality and integrity.
Develop rigorous testing and validation procedures.


Requirements

Demonstrate expertise in data science, underpinned by a robust background in statistical analysis, predictive modelling, and machine learning.
Hands-on expertise and real-world experience with Python, Pandas, NumPy, or equivalent.
Competence in distilling complex data sets into clear, actionable insights.
Acute problem-solving abilities, with a knack for connecting data analysis with tangible operational realities.
We seek individuals who can dissect data and grasp the larger operational canvas, paving the way to enhanced efficiency and performance.


An understanding of the operational nuances in fleet management and logistics is preferred but not mandatory.


Our Team's Way of Working

At Sky Ledge, our values are centred on delivering excellence promptly. Though our team may be compact, each member plays a vital role. We initially favour on-site collaboration, gradually transitioning to a hybrid work model that combines in-office and remote engagements.


Our foundation is built on product innovation, technical excellence, and superior user experience. We highly value collaboration across functions to ensure alignment to address challenges and deliver value to our users.



Quality is our cornerstone; we adhere strictly to unit testing, clean code, and durable solutions.

Accountability is key — we own our work, fix our mistakes, and are forward thinking.




Interview Process

We ensure every applicant receives feedback.
Selected candidates will be invited for an initial interview via phone or video call.
Those advancing will participate in a second-round interview, which may be remote or in-person.
A third interview round may be organised as needed.
Offers of employment will be extended to successful candidate.
""",


    """ 19 Senior Data Scientist Wordwall · United Kingdom
    About the job
We need a Senior Data Scientist who can help our development team discover the truth about user behaviour. You will have experience in a software development context, with excellent mathematical and problem solving skills. You will have a logical mind and deep understanding of evidence and biases. You will collaborate with our development team to create research questions that you’ll then find answers to. You will perform complex analysis to synthesise the evidence then translate this into actionable insights that are well communicated and easily understood.


Our mission is to make it easy for teachers to create interactive games and printables for their students. Our site automates the process of resource design, so teachers can simply enter the content that is appropriate for their class – a list of keywords, definitions, questions or images. Wordwall produces the content in over 60 different templates; for example, gameshow quizzes, crosswords, labelled diagrams and arcade games. It seeks to disrupt the publisher-driven model of paid-for “professionally” made educational content by putting high-quality content creation in the hands of teachers and making that teacher-made content freely accessible through our online community.


We are a small, but growing, team who work remotely across the world. We are obsessive about using data to build a better product. Our 30 million monthly users mean there’s always more to find out. We’ve got a product that works and we’re building for the long-term. We want people who want to stick around, grow with us and help make games-based learning accessible to all.


We are an equal opportunities employer. We support flexible working arrangements - full or part time.


Requirements
Degree in mathematics, physics, computer science, data science or similar
3 years experience in a data science role in a software development context
Skills - databases (SQL+NoSQL), statistics, programming and advanced spreadsheets


Benefits
£50 - 60k per year
30 days paid holiday
Remote and flexible working


#LI-Remote
    """,


""" 14 Data Scientist TriNetX · Freiburg, Baden-Württemberg, Germany
About the job
JOB Offer


Position Title: Data Scientist (Real World Data)

Location: Freiburg, Germany

Who we are:

Located in Freiburg, Germany and Basel, Switzerland, TriNetX Oncology GmbH is a renowned vendor for regulatory grade, fit-for purpose oncology real-world data (RWD) and real-world-evidence (RWE) in Europe. By curating representative, granular, and high quality data in close collaboration with care givers, we analyze the diversity of cancer care across the continent.


TriNetX Oncology regularly delivers comprehensive, in-depth insights to our valued clients and partners within the pharmaceutical industry by providing detailed, representative, and longitudinal analyses on epidemiology, patient profiles, disease characteristics, treatment algorithms, outcome assessments, and institutional attributes. These insights play a crucial role in facilitating external control arms, conducting adjusted comparison analyses, offering HTA support, generating business intelligence, and beyond.


What you bring to TriNetX Oncology GmbH:

· A strong background in Biostatistics, Statistics, Bioinformatics, or a related field (MSc. preferred)
· A track record of working on complex biostatistical analyses.
· Strong programming experience with at least one common programming language and tools such as R, R/shiny,
 Python, Java, Docker, etc., as well as best practices in coding.
· Work experience with medical data, preferably in a regulated environment (e.g., GxP).

· A proven ability to quickly familiarize yourself with new topics and an interest to grow & develop in the domain of
 health care data analysis.

· Strong collaboration skills and experience with version control systems.

· The ability to work in a changing and agile environment with international collaborations.
· Very good communication skills including presentation of results and moderation.
· Fluency in English and German.


What you will be doing:
· Conduct and support the implementation of biostatistical methods and advanced analytics.
· Analyzing data to support External Control Arms (ECA), adjusted comparisons, epidemiological key facts, patient

 profiles, disease characteristics, treatment algorithms and outcome assessments (e.g., time-to-event analyses).

· Development of ETL- (extract, transform, load) and analytical pipelines.
· Harmonization and standardization of various data models.
· Drafting abstracts, manuscripts, and posters for publication in prestigious medical conferences and peer
 -reviewed journals.


What we offer:

· A globally operating, multinational team of experts in a welcoming, communicative, and harmonious work

 environment.
· Specialization in the transformation of Oncology Real-World Data into Real-World Evidence, capitalizing on the

 current trend in the field.
· Exposure to, and collaboration in, advanced analytical methodologies, such as high-profile multivariate analyses,

 external control arms, and predictive and prognostic data modelling.
· Possibilities for personal and professional development on a global scale.
· Authorship in abstracts, manuscripts, papers, and posters, published at high-ranking medical congresses.
· 30 days of annual paid leave.
· A competitive incentive package.
""",


""" Android Development Superhero

About the job:
Randstad Search, Recruitment Consulting Firm, specializes in the search and evaluation of Middle and Top Management profiles. The firm operates in the main French cities. Consultants in the IT & Telecommunications department leverage their expertise to support you in your professional development. Interested in joining a growing French SME and contributing to innovative projects in the field of mobility? Reporting to the Mobile Applications Manager, we are seeking a superhero of Android development who will work on mobility applications. Design and develop Android solutions (routes, transportation, passenger information, ticketing) in an international, multi-app, multi-domain context. Ensure project robustness with maintainable code, adapted to API/Framework changes, and adherence to best practices. Ensure technical coherence, assess developments, and support Product Owners and API services. Supervise junior developers. Work on the industrialization and automation of project delivery, including continuous integration, white labeling, maintenance, and version factorization. Actively participate in pre-sales phases, including estimations, technical challenges, partner and technical base validation, etc. Graduate of an Engineering School or University (Bac + 5). 5 years of experience in Android application development. Good level of English (written and oral). Skills: Native Kotlin/Java development, use of Rest APIs, SignalR. Frameworks Coroutine, RxJava + RxAndroid, Dagger 2, Retrofit + OkHttp. Patterns: MVVM, MVP, Clean Architecture. Mastery of WebSockets, GIT, Cocoapods. Assets: Expertise in CI/CD (Jenkins or other), Firebase, Google Maps. Technical rigor, teamwork in a distributed environment. Global vision of the app lifecycle, transparent communication. Culture of delivering quality, autonomy, proactive attitude.
""",


"""Mobile Applications Developer (Android & iOS)

Profil De Poste:
Under the authority of the Project Director, you will be responsible for developing Android & iOS mobile applications aimed at validating a connected system to contribute to the development of an application whose role is to simulate a complex system and verify its proper functioning.

Your Missions:

Design
Development
Validation activities
Application evolution
Support and expertise
Profile:
With a higher education in computer science, you have experience in mobile application development.

Prerequisites:

Confirmed native Android development
iOS development
Mastery of Android components, as well as the Internet of Things environment
Cloud knowledge: Microsoft Azure
Professional English required
Curious and proactive, you are recognized for your listening skills, technical rigor, writing, analysis, and synthesis abilities. You follow technological developments and are capable of sharing them with those around you.

""",

"""Android Developer

Your Missions:
Integrated into our teams at our Factory or at our clients' premises, you will work on mobile development projects. As an Android Developer, you will be responsible for the following missions:

Developing tasks assigned to you while adhering to specifications
Code review with other developers on the project
Writing unit and functional tests during your development
Industrialization of your developments via our CI (Jenkins)
Participation in Daily Scrum Meetings, Sprint Reviews
Technical Stack:

Language: Java Android / Kotlin
Architecture (preferred): Clean architecture, MVVM / MVI / MVP, dependency injection, Reactive programming
Tools: Fastlane, Git, Jenkins, Jira
Databases: SQL (MySQL, PostgreSQL, SQLServer) and/or NoSQL (MongoDB, Cassandra, Redis)
Offer Reference: yue1m0c8rp

Candidate Profile:
So, ready to become an Amiltonian? Don't hesitate to apply if you recognize yourself:

Graduated with a Bachelor's or Master's degree (Bachelor's / Master's / Engineering School), you have 3 years of experience in a similar position.
You enjoy discovering new functional contexts and understanding the objectives of the applications you develop.
Comfortable in an agile organization, you demonstrate rigor and apply Amiltone quality standards throughout the development process.
In addition to your technical skills, we are also interested in your potential and motivation.
""",

"""Software Development Intern (Full Stack)

VOS MISSIONS:
You will join a development team responsible for creating a scalable, maintainable, and high-value software solution through various technical foundations and market solutions (programming languages, frameworks, and data visualization solutions). Your daily responsibilities will include:

Design and development of next-generation applications (containers, APIs, microservices, NodeJS, cloud-native)
Interventions on legacy applications (Webapps, heavy Java applications)
Incident management: tracing incidents on a JAVA application, proposing a fix, communicating with a client
Votre profil:
You are the ideal person to join our team if...
You are pursuing a Bachelor's Degree +5, engineering cycle in an engineering school or equivalent, and you are looking for a 24-month internship to validate your degree.

Vos compétences:

Ability to write clean, maintainable, and efficient code.
Analytical skills in problem-solving (troubleshooting)
Ability to write documentation and comment code
Mastery of one or more programming languages such as Python, NodeJS, PHP, Java.
Les compétences qui sont un plus:

Knowledge of various frameworks such as JWT, PassportJS, ExpressJS, Angular, or React
Experience in agile development methodologies
Understanding of database technologies such as MySQL, Oracle, or MongoDB
Ability to write SQL / PSQL queries
Experience with containerization tools such as Docker or Kubernetes is beneficial.
""",

"""Full Stack Development Intern (CMS Focus)

Profile Sought:

Education: Currently enrolled in computer development training with a specialization in PHP and CMS, possessing initial experience in full-stack development.
Technical Knowledge: Basic understanding of Drupal, Prestashop, Magento, and front-end technologies such as HTML, CSS, JavaScript.
Analytical Mindset: Ability to grasp client needs and devise tailored solutions.
Motivation and Commitment: Eagerness to learn and advance in a dynamic and innovative environment.
Interpersonal Skills: Strong communication abilities and capability to collaborate within a team.
Opportunities and Benefits:

Practical Experience: Obtain concrete and relevant experience in Full Stack development focused on CMS.
Employment Prospects: The internship is designed as a pathway to potential employment following completion of training.
Stimulating Environment: Work in an environment conducive to innovation and personal growth.
""",

"""Full Stack Development Intern

What You'll Do If You Join Us:

Front-end and/or back-end development as per project needs
Gathering user requirements
Assessing the feasibility of client needs
Designing a functional and technical solution that meets these needs
Implementing this solution
Defining the validation framework for your solution in light of client needs.
Your Profile:
You are currently pursuing a Bachelor's +5 degree in an engineering school or within a university program with a specialization and already have one or more initial experiences, whether personal, within your curriculum, or in a professional setting.
You have a good command of front-end programming languages (HTML, CSS, JavaScript) and/or back-end (Java, PHP).

Familiarity with CMS such as Jahia and/or Drupal and an interest in ergonomic, UX/UI issues would be a plus.
You are capable of proposing solutions tailored to needs and wish to participate in the continuous improvement of practices.
Your natural curiosity drives you to want to continue to improve yourself, with the aim of fully contributing to the completion of your mission.
""",

""" International Technology Solutions Intern

What You Can Expect From the Mission:

Skill and responsibility enhancement
Service development in collaboration with PwC consultants from various teams and clients.
Our end-to-end technology solutions consultants understand the full spectrum of Cloud and Digital solutions, as well as different technological components and their integration into the company's infrastructure. They effectively collaborate with other teams to define technological objectives, evaluate solution options, and design architectural solutions that meet strategic objectives and operational requirements of our clients.
Working with client teams and our Technology teams, our consultants implement cost-effective and efficient digital solutions, assuming a leadership role from design to delivery to ensure that technical solutions continue to meet business requirements and strategic vision.
Technical and functional reference for our teams responsible for our transformation offering.
Acting as a technological design authority on technology transformation programs.
Monitoring technological developments to better anticipate our clients' needs
What We Expect From You:

Seeking a full-time internship for 6 months.
Currently studying for a Bachelor's +5 degree, engineering degree, or master's degree in networks and telecommunications or a specialized master's degree in communication systems and networks, networks and information systems for businesses, etc.
Knowledge in areas: Cloud, Development, Scripting, Network, Integration, etc...
Some knowledge in Digital and multi-channel technological solution architecture, covering all technological layers from presentation layers to infrastructure layers.
Good analytical, synthesis, and listening skills.
Independent and curious-minded.
Sensitivity to current societal issues.
Fluent in English.
""",

"""Software Unit Testing Engineer

Essential Duties and Responsibilities:

Design, develop, and execute software unit tests for real-time embedded systems using Ceedling, while adhering to ASPICE Level 2 standards.
Follow Casco Software Development Process & its improvements in line with ASPICE.
Develop unit test plans and test cases for various components and features of embedded systems.
Collaborate with software engineers, hardware engineers, and system integrators to identify and resolve issues related to software unit testing.
Develop and maintain automated test scripts and frameworks for regression testing.
Debug and troubleshoot issues related to software unit testing.
Create and maintain documentation related to software unit testing, following ASPICE standards.
Ensure adherence to software development best practices and coding standards, as well as ASPICE Level 2 standards.
Develop the software unit test product by following industry and automotive standards.
Actively participate in software and hardware reviews if necessary.
Accountable for assigned software project milestones.
Education/Training & Qualification Requirements:

Degree in Electrical Engineering or Computer Engineering, or equivalent.
3+ years of experience in software unit testing for real-time embedded systems.
Proficiency in C programming language.
Experience with Ceedling tool or similar tool for software unit testing is highly desirable.
Strong understanding of software development best practices and coding standards.
Excellent problem-solving and analytical skills.
Ability to work independently and in a team environment.
Excellent written and verbal communication skills.
Automotive experience is a plus.
Core Competencies/Knowledge:

Proficiency in MS Office Products such as (Word, Excel, PowerPoint, and Outlook).
Knowledge of software development tools and languages such as C and Assembly.
Knowledge of micro-controllers such as ARM, Microchip, TI, and NXP.
Knowledge of CAN and LIN communication.
Knowledge of software configuration management tools (Jira, R4J, Doors, Bitbucket, Git, etc.).
Knowledge of electrical circuits, transducers, sensors, data acquisition, and laboratory equipment.
Knowledge of automotive software development standards, such as CMMI and ASPICE.
Knowledge of Functional Safety (ISO-26262) and Autosar would be a plus.
""",



"""2 Data Scientist - Asset Management

(Tech stack: Data Scientist, Python, R, Data Science, Machine Learning, Artificial Intelligence, Tableau, Engineer, Senior, Leader, Technical Lead)

Our client, founded in 1930, is a leading investment manager with offices across Europe, Asia, and North America. Managing over £120 billion across all asset classes and employing over 2000 people worldwide, they are pioneering revolutionary applications that have garnered significant attention in the trade press.

Due to this, there are several Greenfield software development projects requiring talented Data Scientists to build software supporting their progression. We seek Data Scientists who can hit the ground running and play a crucial role in crafting stylish and innovative products. You'll have access to ample resources to aid in achieving this goal.

We are seeking Data Scientists with proficiency in some or all of the following (full training provided to fill any skill gaps): Python, R, Data Science, Machine Learning, Artificial Intelligence, PyTorch, TensorFlow, Scikit-learn, Pandas, Providers, OAuth2, Tableau, SQL, MS SQL Server, PostgreSQL, Spacy, NLTK, FlairNLP, Fast API, Django/REST Framework, REST APIs, RDF/XML, JSON-LD, IIIF, UI/UX, and DevOps.

All Data Scientists can anticipate the following benefits:

Performance-based Bonus
Remote working
34 Days Holidays per year
Life Insurance
Ongoing training and certifications
Health Insurance
Reduced gym membership costs
And much more
Location: London, UK / Remote
""",

""" 4 Machine Learning Engineer

Devoteam is seeking a highly skilled and motivated Machine Learning Engineer to join our growing Data Science and Engineering team. The ideal candidate will have a strong background in machine learning, software development, and the ability to work effectively in a fast-paced, collaborative environment.

This role will be instrumental in developing and implementing cutting-edge machine learning models to solve complex business problems and drive innovation within the organization.

Key Responsibilities:

Develop and maintain production-ready code, ensuring high quality, efficiency, and scalability.
Build and deploy AI models into production with a focus on scaling, monitoring, and performance.
Implement data preprocessing, feature engineering, and model evaluation techniques to optimize machine learning models and ensure their effectiveness.
Continuously monitor and evaluate model performance, making adjustments and improvements as necessary to ensure ongoing effectiveness.
Deploy machine learning models into production environments, integrating them with existing systems and infrastructure.
Utilize advanced analytics tools such as Alteryx to automate machine learning pipelines.
Qualifications:

A minimum of 3 years of experience in machine learning and software development.
Strong proficiency in Python, with experience in machine learning libraries such as TensorFlow, Keras, and Scikit-learn.
Strong software development skills, with experience in version control systems such as Git and agile development methodologies.
Knowledge of advanced analytics tools such as Alteryx.
MLOps experience.
Proficiency with containerization, orchestration, and deployment.
Additional Information:

The roles listed require mobility flexibility, allowing individuals to work interchangeably between Tunis and Riyadh (Saudi Arabia).
""",

"""Machine Learning Engineer - InstaDeep

Are you a Machine Learning Engineer focused on gathering information and generating knowledge on AI using both theoretical and experimental means? If so, then keep reading….

As a Machine Learning Engineer at InstaDeep, your goal is to develop and implement novel ideas while building simple and sustainable software solutions. Among the tasks, you are responsible for developing prototype applications, providing software design and programming support to research projects, and implementing software libraries.

In this role, you will report to the Senior Product Lead at InstaDeep. Please note that this role may require overseas travel.

Responsibilities:

Develop novel algorithms and research ideas in fields such as machine learning, deep learning, and reinforcement learning.
Bridge the gap between research and products by integrating new fundamental research into applied projects.
Collaborate with the Engineering team to design and run experiments, including developing and evaluating new algorithms and implementing known ones.
Design and implement algorithms to best leverage modern hardware and distributed computing systems (CPUs, GPUs, TPUs, Cloud, etc.).
Write and maintain high-quality, maintainable, and modular code with concise documentation and tests together with researchers and engineers.
Report and present experimental results and research findings clearly and efficiently, both internally and externally, verbally and in writing.
Qualifications:

MSc/PhD degree in Computer Science or a related scientific field.
At least 1 year of professional experience in AI or similar fields.
Experience in developing and debugging in C/C++, Python, or similar languages.
Experience using deep learning frameworks such as PyTorch, Tensorflow, and/or Keras.
Experience with storage systems, distributed systems, HPC, compilers, and/or CUDA programming is a plus.
Research and software engineer experience demonstrated via an internship, contributions to open source, work experience, or coding competitions.
Excellent communication skills and collaboration with researchers and developers.
""",

"""Responsibilities:
within our team you will be in charge of:
The development and validation of STM32 peripheral drivers for new products starting from
design specification up to official release on the Web.
Continuous enhancement of HAL/LL validation environments to ensure a full feature coverage
Leading and participating to the activities of HAL/LL drivers validation environments
automation: SW&HW setup, ACI configuration and follow-up, internship supervision…
Defining, development and validation applicative examples for STM32 peripheral
Work in collaboration w/ Maintenance and GitHub teams to ensure high quality of deliverables.
Help to fix reported bugs in line with defined maintenance strategy for STM32Cube firmware
packages
Required skills:
Embedded & Realtime Software Development - C/C++ and assembly languages (Debug -
Profiling)
Very good ARM Cortex-M architecture knowledge (Cores, Bus structures, Caches …)
Strong low level Drivers Development and Validation experience
Collaborative and team spirit
Cross-functional contribution
Experimented in:
Configuration management (git, gerrit, github, repo) will be appreciated
Common usage on classical development environment (IDEs such as IAR, Keil, Eclipse)
Scripting competencies (python, perl) will be appreciated - Typescript will be a plus
Good knowledge & usage of electronic testing tools (oscilloscope, multimeter, frequency
generator, …)
Excellent English written and verbal communication; ability to explain complex concepts
job:
Reporting to the Head of Acquisition, the Influencer Acquisition Manager will drive strategies for
influencer and brand ambassador partnerships, enhancing brand visibility, boosting business
performance, and increasing user engagement. The ideal candidate will have a minimum of 2
years of experience in influencer marketing, with a focus on crypto and iGaming sectors.
Responsibilities:
● Identify, approach, and onboard influencers aligned with the brand's ethos.
● Cultivate and maintain relationships with influencers and partners.
● Explore new collaboration opportunities to expand brand reach.
● Collaborate with partners to drive user acquisition and ensure tangible ROI.
● Monitor and evaluate partnership efficacy, aligning with set KPIs.
Requirements:
● 2+ years of experience as an acquisition manager in iGaming, preferably in crypto
gaming.
● Strong analytical and negotiation skills.
● Results-driven mindset with a track record of achieving targets.
● Excellent organizational and communication skills.
● Comfortable working remotely with flexible shifts.
● Experience in tracking conversion and providing detailed reporting.
What We Offer:
● Fully remote working.
● Competitive salary.
● Discretionary company bonus scheme.
● 25 days of holiday.
● Young working environment.
● Career progression opportunities.
""",

"""Legal Officer - Litigation and Collective Interest Missions

Key Responsibilities:

Litigation Management:

Prepare and oversee litigation proceedings before appellate courts: drafting pleadings, liaising with lawyers, enforcing court decisions.
Ensure qualitative monitoring of pleadings: quality of arguments and monitoring recent case law, tracking new opposing arguments and adhering to deadlines for filing pleadings, analyzing court decisions to determine appeals.
Maintain up-to-date records of litigation files integrated into the Fiva information system.
Ensure physical file management for archiving purposes.
Participation in Collective Interest Missions specific to Litigation:

Improve pleadings and participate in monitoring jurisprudential developments.
Share information on case law decisions.
Contribute to updating pleadings and developing new arguments.
Analyze case law: identify new opposing arguments, consequences of rendered decisions, and act as an alert resource.
Participation in Collective Interest Missions common to the establishment:

Conduct documentary and jurisprudential research.
Draft legal notes.
Participate in ad-hoc projects: compile statistics, internal control operations.
Qualifications:

Hold a Bachelor's degree +5 in Law or Certificate of Aptitude for the Legal Profession (desirable).
Demonstrated proficiency in drafting pleadings.
Mastery of compensation principles for bodily injury (full compensation), social security law, especially AT/MP regimes.
Professional experience in a law firm (desired).
Proficiency in MS Office tools: Word, Excel, PowerPoint, Outlook.
Analytical and synthesis skills.
Strong organizational and prioritization skills.
Commitment to rigor, adherence to procedures, and deadlines.
Join us if you have a passion for law and seek to contribute to the pursuit of justice with precision and dedication.
""",

"""Laboratory Technician - Sample Processing and Analysis

Job Description:

Your Mission:
Within the preparation department, your tasks will include:

Ensuring the pre-analytical processing of samples.
Handling non-conformities upon reception.
Preparing analyzers, reagents, and processing samples.
Transmitting and sending samples to specialized laboratories.
Performing examinations on analyzers using associated software and/or manual techniques.
Interpreting, comparing with previous results, entering, and technically validating examination results.
Transmitting examination reports.
Participating in the classification, archiving, and storage of documents.
Managing temporary storage, registration, and storage in a serum bank if necessary, as well as the disposal of samples.
Managing reagents/consumables: receipt, validation, storage, traceability.
Using the Laboratory Management System (LMT) to search for patient data and their possible updates and participating in customer service.
""",

"""Medical Assistant Position in a General Practitioner's Office

Description

A general practitioner is seeking a Medical Assistant to improve patient care and reduce administrative burden. As a Medical Assistant, you will work closely with the physician and assist in patient care: reception, managing pre-consultations, reviewing preventive exams, secretarial tasks, and entering reports or CERFA forms.

The position is part-time, at least 17.5 hours per week, according to the national collective agreement for medical office staff.

Responsibilities:

Greeting patients and updating their information in the electronic record.
Preparing patients for medical consultations: vital signs, reviewing preventive exams, vaccinations, etc.
Assisting the physician during certain technical procedures, including instrument sterilization.
Assisting the physician during consultations with newborns and young children.
Scheduling and coordinating patient appointments.
Profile and Qualifications:

Previous experience in a medical office.
Interpersonal and administrative skills.
Writing skills.
Ability to work effectively in a dynamic medical environment.
Ability to maintain patient medical information confidentiality.
""",

"""Web Developer Apprentice Position at Leading Digital Services Company

Description: ISCOD, a specialist in Digital Learning training, is seeking a Web Developer (F/M) apprentice in alternating apprenticeship contract for the world leader in digital consulting and services. This position is for preparing one of our state-recognized diploma courses ranging from level 5 to level 7 (Bac+2, Bachelor/Bac+3, or Master/Bac+5). Choose the next-generation apprenticeship with ISCOD!

Responsibilities: As part of one of our business teams, you will participate in the following stages of the project:

Detailed design
Implementation, frontend and/or backend development
Unit testing and integration
Updating technical documentation
Application of quality standards: HTML5, CSS3, JavaScript (VueJs/React/Angular/NodeJS Framework), Webservices, continuous integration (Jenkins, GIT). Primary involvement in one of the following backend layers: Java, PHP, or .Net
Profile:

Education: Engineering school or university degree
Oral and written communication skills in English
Autonomy, active listening, critical and constructive thinking, curiosity, dynamism, ability to integrate into a team
Knowledge in web development
""",

"""Operations Apprentice at Cyberwatch, a Framatome Subsidiary

Description: Cyberwatch, a French software security company and subsidiary of Framatome, assists businesses, administrations, Critical Infrastructure Operators (OIV), and Essential Service Operators (OSE) in reducing their cyber risk through continuous analysis and relevant reports tailored to their business environment. Cyberwatch develops and offers two products: Cyberwatch Vulnerability and Cyberwatch Compliance Manager. The Operations team handles technical interactions with clients and performs the following tasks:

Deployment of containerized application on Linux scan clusters
Training Chief Information Security Officers (CISOs) and SI security administrators in the use of our solutions
Identification of client-requested features
Implementation of scripts using our solutions' APIs (e.g., integration of our software with third-party products)
Study and response to clients' technical issues. Our tech stack includes:
Ruby on Rails for the core of our products and remote management via SSH / WinRM / SNMP
JavaScript ES6 + VueJS for interactive elements
Python for Cyberwatch agents and our web scan engine
Docker for orchestration and deployment of our products. Training and support for newcomers are part of the integration and provided by managers recognized for their expertise well beyond Cyberwatch. The goal is to lead you to expert level in vulnerability and compliance management. Position based in Massy (near RER+tram12) with telecommuting days, free health insurance, and company restaurant.
Profile: Apprenticeship duration: 12 to 36 months, the following skills will be developed:

Windows / Linux system administration
PowerShell or Bash
Ruby or Python
Bonus: Docker.
""",

"""Cybersecurity Intern at CERT-CEA

Description: The Information Systems Security Department (S3i) operates in the field of cybersecurity, defining information systems security policies. As part of the CERT-CEA team, you will learn and participate in various activities according to the service's needs:

Incident handling (SOC analyst) and monitoring of their remediation
Improvement of supervision infrastructure (development of alerts and detections)
Strengthening investigation capabilities (sandboxing, proof of concept, etc.)
Conducting pentests on internal systems to assess security
Forensic analysis (search for IOCs)
Open-source threat intelligence (OSINT/CTI) monitoring
Candidate Profile: Currently pursuing a BAC +5 degree (engineering school, university) in the field of computer science with a keen interest in cybersecurity. Passionate about cybersecurity, you aim to work in an environment that allows you to develop skills in various complementary domains:

Securing and supervising an operating system (Windows, Linux, Mac)
Analysis of logs and event logs (SIEM) from operating systems, services, and network equipment
Threat detection, investigation, and management tools (Splunk, TheHive, MISP)
Scan and configuration audit tools (Nessus, nmap, etc.)
Pentest methods (Kali, etc.)
Forensic analysis methods and techniques
Software development (python, powershell, etc.)
Candidate Criteria: Degree pursued: Master's Degree (Bac+5 - Master 2).
""",

"""Human Resources Officer (CDI Full-time)

Description: The Œuvre de la Croix Saint Simon Foundation is recruiting a Human Resources Officer (H/F) for a full-time permanent position. Reporting to the Human Resources Manager, your main responsibilities within the Human Resources Department include:

Ensuring daily HR management and responding to managers' and employees' requests on various HR topics (drafting employment contracts and amendments, monitoring probationary periods and contract terminations/secondments, monitoring medical visits, drafting certificates, and responding to various employee correspondence).
Participating in various HR development projects (especially diversity policies including disability) and supporting these projects with managers and employees.
Updating and monitoring HR data.
Participating in cross-cutting projects of the Human Resources Department.
Contributing to the continuous improvement and professionalization of Personnel Administration activities.
Supporting the deployment of new tools/methods of work.
Daily support for employees and managers on all HR issues.
Managing incapacity, conventional, and disciplinary termination files.
Responding to requests from external institutions.
Monitoring changes in labor legislation.
Qualifications:

Bachelor's degree in HR.
A first experience of 3 years is required in the field of human resources.
Adaptability, versatility, and interpersonal skills.
Ability to convince and highlight expertise.
We look forward to hearing from you! Get ready, get set, apply! We support you throughout your career by offering:

A comprehensive and individualized integration program.
A skills development plan to support your growth.
Improvement plan for working conditions, QWL with a dedicated social service for employees, Revitalize yourself (sophrology, prevention of psycho-social risks, occupational psychologists).
Possibility of childcare / Housing assistance.
Additional days off: paid leave weeks, seniority, recovery of public holidays falling on weekly rest days.
Profit-sharing bonus.
Referral bonus of €300 gross.
Remuneration determined according to experience in accordance with the FEHAP collective agreement (CCN 51).
Desired Profile:
Experience:

Required experience of 3 years.
Language:
French.
""",

""" Chargé d'Études Geomarketing

Description: We are looking for a passionate and motivated Geomarketing Studies Officer to join our dynamic team. In this role, you will be responsible for conducting market studies, analyzing geographical data statistically, and contributing to the development of our software in collaboration with our experts.

Responsibilities:

Conduct market studies and analyze geographical data.
Utilize geodata: collect, rectify, analyze, cross-reference, model, visualize, and communicate.
Configure the Geoptis solution software for turnkey delivery to users.
Collaborate with development teams to enhance our software.
Present analysis results and strategic recommendations to clients.
Ensure the quality and relevance of the data used.
Qualifications:

Degree in Geographic Science, Geomarketing, Statistics, or related field.
Previous experience in market studies and geospatial data analysis.
Proficiency in GIS tools and data analysis software.
Excellent communication and presentation skills.
""",

"""5 Data Engineer Position

Description:
You have a Computer Engineering profile (BAC +5) and have already completed projects or missions as a Data Engineer on one of the main cloud providers (Microsoft Azure, Amazon AWS, Google GCP).
You have used managed services to handle data ingestion and transformation (Azure Data Factory, Synapse, Azure Functions, Events Hub, Storage Account, SQL Database, Azure DataWarehouse, or equivalent on AWS, AWS Glue, etc.).
You master CI/CD pipelines and embrace the DevOps culture.
You are capable of optimizing existing workflows.
You master SQL / NoSQL databases.
The Hadoop ecosystem (HDFS, Pig, Hive, Sqoop, Flume,...), Spark or Elasticsearch hold no secrets for you.
You master languages: Java, C++, Python, Shell, Scala, and GO.
You master Linux or UNIX environments.
You are autonomous and able to build data pipelines, with experience in production and application maintenance.
You have already programmed in Scala or worked on Machine Learning algorithms.
You are certified in AWS, Azure, or GCP stacks.
Your Missions
Within one of our Business Units in Consulting, Expertise, Delivery, and Data-related services, you will join a team of 70 Data Specialists (Data Engineers, Big Data, Data Scientists, Data Analytics, DevOps, CloudOps, Data Architects...), capable of assisting our clients in implementing a global cloud data strategy.
You will Intervene On The Following Topics

Design and implementation of Cloud platforms;
Design and implementation of integration flows (batch or real-time mode) for structured/unstructured and voluminous data;
Technical and functional optimization in terms of software performance and quality;
Skills transfer and training animation;
Recommendation of tools and/or technologies and continuous technological watch;
Recommending, implementing, and industrializing the most suitable and efficient solutions for our clients;
Participating in the design and implementation of the best technological and methodological solutions to serve our clients' DATA and AI use cases.

""",

"""Apprentice Control Officer - Retail Banking

Daily Missions:
Are you looking to train in the banking sector? Do you seek a position offering a variety of tasks, a cross-functional vision, and continuous teamwork?
As an apprentice within a team of controllers, you'll secure Finance processes in Retail Banking in France. You'll contribute to animating the framework across 15 controller teams in France and internationally. You'll have a comprehensive view of data, ensuring compliance before submission to internal or external control bodies (CACs, regulators). In short, nothing escapes your attention!
Specifically, under the supervision of your tutor and/or manager, you'll:

Perform control missions with our expert team on significant risk areas related to regulatory obligations, accounting, financial management, ALM, or taxation.
Propose effective improvement measures to strengthen internal control mechanisms.
Analyze the deployment of controls and the results of quarterly campaigns.
Contribute to continuous improvement and digitalization of our work.
Participate in animating the Level 2 Finance Control framework on the French and International Networks, overseeing local Level 2 Control teams.
Verify that quarterly indicators reported by local teams are reliable and reflect the quality of the framework and work performed.
Could this be you?

You are pursuing a Bachelor's +4/5 degree in University or Business School with a specialization in Audit and Finance.
You are rigorous, curious, adaptable, and have good interpersonal skills.
Proficiency in office tools: Excel, Word, and PowerPoint.
Fluency in English! You're our ideal candidate!
""",

"""6 Senior Data Scientist - Deep Learning Specialist

Job Description:
Ekimetrics is a leader in data science and AI solutions. Since 2006, we have been using data science to optimize marketing performance, business outcomes, and the transition to more sustainable performance.
Your responsibilities will include:

Keeping abreast of the state of the art in deep learning, with a focus on generative AI.
Conducting research to address new client needs.
Adhering to best coding practices to ensure industrialization, collaborating with our Solution experts.
Sharing your knowledge internally by providing expert support.
Acting as a Senior Data Scientist on Data Science projects with our clients.
Profile and Skills Required:

Researcher or recent PhD graduate in Computer Science specializing in deep learning applied to NLP, with several publications in high-level international conferences.
Experience in development methodologies and best practices: unit testing, version control, CD/CI.
Proficiency in Python.
Mastery of libraries such as Pytorch, numpy, sklearn, and Transformers.
In-depth knowledge of probability, mathematics, and statistics.
Fluent in English.
""",

"""IT Administrative Assistant

Job Description:
Acass, a recruitment agency, is searching for an IT Administrative Assistant (H/F) for one of its clients, for a renewable 1-month interim mission. The position is based in Lyon 7th (69). You will join the end client of an ITSS specializing in the management of IT installations. Your responsibilities will include compiling and consolidating computer data for the establishment of client site files (identification of switches and other IT equipment), creating PowerPoint presentations, data entry into VISIO software, and drafting IT procedures.

Profile Description:
Holder of a BAC +2 degree or equivalent in the field of IT, with knowledge of office tools such as SAP/Excel and familiarity with VISIO software.
""",

"""React Native Developer

Job Description:
Join an experienced team in a natural environment just minutes away from Paris, with technical support and project managers to guide you through your mission.
Conditions Offered:

Position available as soon as possible in Montlignon (95).
Contract Type: Permanent
Level: Experienced (minimum 2 years of experience in REACT NATIVE mobile development)
Remuneration: According to profile
Benefits:
Possibility of telecommuting after the trial period (depending on profiles)
Technical documentation and magazines available.
Desired Profile:
Experience:

2 years
Skills and Know-How:
Web application development
React.js
Designing a web application
Developing an application linked to a database
Conducting technical diagnostics
Gathering and analyzing client requirements
Testing software, information systems, and applications
Professional Skills:
Demonstrating autonomy
Showing rigor and precision
Working in a team
Education:
Bac+2 or equivalent
Language:
French
""",

""" Android/iOS Mobile Developer

Job Description:
We are looking to expand our team with an Android/iOS Mobile Developer.

Position Profile:
Under the authority of the Project Director, you will be responsible for developing Android & iOS mobile applications aimed at validating a connected system to contribute to the development of an application that simulates a complex system and verifies its proper functioning.

Your Missions:

Design
Development
Validation activities
Application evolution
Support and expertise
Profile:
With a higher education in computer science, you have experience in mobile application development.

Prerequisites:

Confirmed native Android development
iOS development
Mastery of Android components, as well as the Internet of Things environment
Cloud Knowledge: Microsoft Azure
Professional English required
Curious and proactive, you are known for your listening skills, technical rigor, writing abilities, analytical and synthesis skills. You keep up with technological advancements and are able to share knowledge with those around you.
""",

"""Mobile Software Developer

Job Description:
As a Mobile Software Developer, your role encompasses various responsibilities within software and mobile application development.

Key Responsibilities:

Designing, developing, and maintaining software and mobile applications.
Implementing unit tests and integrating projects into the continuous integration platform.
Participating in the design of infrastructure and application architecture with the tech lead or software architect.
Understanding the mobile environment, including multiple platforms (mobile, tablet, smartphone).
Operating within the project environment (agile Kanban) and contributing to technical briefings.
Technical Environment:

Android using Java and Kotlin or iOS using Swift and Objective-C.
Profile:
Coming from an educational background in the field, with a minimum of 2 years of experience, you are passionate about web development in an agile environment with innovative technologies and have a good understanding of the C# .NET ecosystem.
""",

"""Mobile Developer

Job Description:
Your missions?
Integrated into our teams on our projects in the Factory or at our clients, you will be involved in a mobile development project.
As a Mobile Developer (M/F), you will be responsible for the following missions:

Designing efficient, reliable, and scalable mobile applications.
Proposing innovative technical solutions.
Participating in the design and development of multiple mobile application projects.
Participation in the Daily Scrum Meeting, Sprint Review.
Technical Stack:
Android - iOS - Swift - Kotlin

Profile Description:
Don't hesitate to apply if you recognize yourself.
With a degree equivalent to Bac+3/5 (Bachelor's/Master's/Engineering School), you have at least 3 years of experience as a Mobile Developer.
You enjoy discovering new functional contexts and understanding the objectives of the applications you develop.
Comfortable in an agile organization, you demonstrate rigor and apply Amiltone's quality standards throughout the development process.
""",

""" Experienced Mobile Developer

Job Description:
We are looking for an experienced Mobile Developer to join our team. You will be involved in the entire development cycle of our application, from conception to maintenance. Your mission: to provide maximum value and a quality user experience to our clients.

Key Areas of Responsibility Include:

Planning and Design: Propose and develop new features in collaboration with the Product team.
Development: Implement identified enhancements using appropriate languages.
Project Management: Participate in the grooming phase to maximize spec quality.
Collaboration and Communication: Ensure continuous documentation.
Quality Assurance: Conduct tests to detect bugs, performance issues, and security vulnerabilities (unit, integration, etc.).
Maintenance and Updates: Stay responsive to production, any incidents, and address bugs as needed.
Technical Stack:

Backend: Node.js / GraphQL / Typescript / Temporal.io / MongoDB / Microservices
Frontend: React.js / Typescript / Vite.js
Mobile: React Native / Typescript
Profile Requirements:

3 to 5 years of minimum development experience.
Proven experience in mobile development, especially with React Native.
Mastery of the technologies mentioned in the technical stack.
Ability to work in a team and communicate effectively with other project members.
Attention to detail and focus on quality and performance.
Ability to adapt quickly to changes and learn new technologies.
""",

"""Full Stack Web Developer

Job Description:

Participate in the design, development, and maintenance of dynamic web applications.
Implement web programming languages (HTML, CSS, JavaScript) and frameworks (React, Angular, Vue.js).
Integrate backend solutions (PHP, Python, Node.js) and databases (MySQL, PostgreSQL).
Adhere to best development practices and web standards.
Identify and analyze user needs.
Propose technical and ergonomic solutions.
Perform testing and validate functionalities.
This list of missions is not exhaustive.
Profile Requirements:
As part of the Bachelor Full Stack Developer - Data & DEVOPS or Mastère Full Stack Web Developer training program, you should have the following qualities/skills:

Strong knowledge of object-oriented programming (OOP) with at least one language (Java, Python, C#, C++).
Mastery of fundamental web languages (HTML, CSS, JavaScript).
Appetite for popular web frameworks (React, Angular, Vue.js).
Interest in backend technologies (PHP, Python, Node.js) and databases (MySQL, PostgreSQL).
Team spirit, rigor, and adaptability.
Curiosity, willingness to learn, and progress.
""",

"""Mobile Developer

Mission:
Within the Grand Public and Digital Branch (BGPN), the Mobile Factory has been established to foster synergies and expertise in iOS and Android. It brings mobile expertise to our partners, including business units such as Digital Identity, Digiposte, Laposte.fr, BSCC, and BUGP. This entity develops applications for La Poste, such as La Poste, La Poste Pro, Youpix, Digiposte, and Digital Identity. The Mobile Factory consists of a team of 20 collaborators, including Scrum project managers, tech leads, and developers, of which 45% are women. Responsibilities:

Provide support to the La Poste En Ligne mobile team for handling small functional and technical enhancements on the PART and PRO applications.
Develop small functional and technical enhancements on the PART and PRO applications.
Develop unit tests.
Update libraries.
Profile:

Proficiency in Office 365.
Technical Skills: Clean architecture and MVVM, Cordova, Foundation, UIKit, Kotlin, Android development kit (Android SDK) using tools like Eclipse, Android Studio, or Java Development Kit (JDK).
Behavioral Skills: Curiosity, good communication skills.
Education and Experience:
Bachelor's degree (Bac +4/5).
""",

""" IT Developer

Your Missions:

Analyze needs, design, and develop applications.
Develop system tools, websites, APIs.
Set up tests and acceptance tests, collaboration tools, and an intra-company communication platform.
Maintain, develop, and optimize the Intranet, website, and EDM.
Monitor and maintain existing programs.
Participate in the development and continuous improvement of the Infor M3 ERP.
Optimal use of MS Office.
Technical Environment: JAVA, JAVASCRIPT, API, WS, CSS, PHP, HTML, XML, CMS, VBA, SQL, MS SQL Server, MySQL, Access, Eclipse, Server Mapping MEC, Document server MOS, MS OFFICE.

Your Profile:
Coming from a computer science background (Bac +4 level), you have 5 years of experience in a similar position.
""",

"""Mission Description: Mobile Developer

In the context of our business growth, we are hiring our future mobile developer.

Your Role:
As a member of our Tech team and under the supervision of a project manager, you will be integrated into a team of 5 other experienced developers.

Main Responsibilities:
You will mainly work on the design and development of a mobile and tablet application (Android/IOS).

Project Objective:
The goal is to completely rewrite the Android and Apple application of a cash register solution using AngularJS / Cordova / Java (for peripheral access). The project consists of a web application (back office and website) and a mobile application intended to be used on tablets or smartphones.
""",

"""2 Data & Analytics Consultant

Within Technology Consulting, Data & Analytics is strengthening its teams. You will join a dynamic, enthusiastic team and have the opportunity to work on transformative and innovative projects.

Key Responsibilities:

Develop and implement algorithms to analyze large datasets.
Use Python skills for data manipulation.
Create and optimize SQL queries for database management, including data modeling and schema design.
Participate in the entire lifecycle of AI models, from data preparation to model deployment.
Collaborate closely with cross-functional teams to understand client needs and provide data-driven solutions.
Required Qualifications:

Minimum of 1 year of professional experience.
Experience with Python, Django including understanding of data structures and object-oriented programming best practices.
Proven SQL skills, with the ability to develop queries and experience in data modeling.
Experience with Machine Learning principles and techniques.
Analytical mindset, problem-solving skills, creativity, and openness to addressing complex software problems.
Additional Qualifications (nice-to-have):

Experience with Alteryx.
Knowledge of Generative AI and Prompt Engineering best practices.
Experience with the SAS ecosystem and SAS programming.
""",

"""Mobile Developer - High-Tech Projects

Description:
To support our French and international partners, we are looking for Mobile Developers for high-value technological projects in IT & Digital. You will have the opportunity to:

Be involved in the entire project lifecycle from consulting/design phases to solution deployment.
Understand business needs and functional analysis.
Design, develop, and integrate applications.
Test applications and handle any malfunctions.
Adhere to development methodologies and processes.
Implement best practices for usage and development.
Provide user training for application usage.
Technical Stacks:
Android: Java / Kotlin
iOS: Swift / Objective-C / MacOSX / XCode
Dart: Flutter

Profile:

Passionate about development, architecture, and new technologies, you want to be part of an organization making a real impact in the digital revolution.
Holding an engineering degree or equivalent university degree (BAC+5), you have significant experience in developing Android, iOS, or Flutter mobile applications.
You enjoy facing daily challenges, working independently, and making proposals to bring added value to your projects.
Your interpersonal skills and customer contact abilities are essential qualities for success in this role. Moreover, you want to be involved in the development of a growing company.
You maintain a continuous watch on technologies and can convincingly advocate for innovations in our field.
""",

"""Influencer Acquisition Manager - Crypto & iGaming

Description:
As an Influencer Acquisition Manager, you will report to the Head of Acquisition and drive strategies for influencer and brand ambassador partnerships in the crypto and iGaming sectors. Your role will focus on enhancing brand visibility, boosting business performance, and increasing user engagement.

Responsibilities:

Identify, approach, and onboard influencers aligned with the brand's ethos.
Cultivate and maintain relationships with influencers and partners.
Explore new collaboration opportunities to expand brand reach.
Collaborate with partners to drive user acquisition and ensure tangible ROI.
Monitor and evaluate partnership efficacy, aligning with set KPIs.
Requirements:

Minimum 2 years of experience as an acquisition manager in iGaming, preferably in crypto gaming.
Strong analytical and negotiation skills.
Results-driven mindset with a track record of achieving targets.
Excellent organizational and communication skills.
Comfortable working remotely with flexible shifts.
Experience in tracking conversion and providing detailed reporting.
""",


"""Cloud Engineer (F/H) - Apprenticeship

Description:
Welcome aboard! The Global Infra Transformation Department is seeking a Cloud Engineer for an apprenticeship position. Functionally, our clients (various Carrefour Business Units) should be able to be autonomous and perform as much "self-service" as possible on infrastructure changes, often focused on security equipment configuration and service exposures. We are client-centric, handling complexity to make usage easier for our clients. Acting as an internal Cloud Service Provider, we provide Cloud foundations for all Carrefour projects. We build and run shared infrastructures for different types of production workloads. We continuously improve our service through increasingly advanced automation (self-healing, immutable) and utilize SRE best practices.

Missions:
In this role, you will:

Develop and maintain Infrastructure as Code (IaC) models.
Implement and manage Continuous Integration/Continuous Deployment (CI/CD) pipelines for cloud resources, on time and with quality.
Ensure that cloud infrastructure meets security and compliance requirements.
Collaborate with cross-functional teams to identify and resolve technical challenges and bottlenecks.
Stay up-to-date with the latest industry trends, best practices, and cloud computing technologies.
Your Profile:

Passionate about technology, especially everything related to the Cloud.
Strong foundation in Python (API, infra...) and Linux.
Familiarity with the principle of "least privilege".
Everything is done "as code" through our CI/CD platform (Terraform, Ansible, Jenkins, GitLab).
The ideal candidate will be responsible for implementing public cloud infrastructure and supporting the evolution of the GitOps/SRE framework to meet the needs of our organization.
""",

"""Experienced Cloud Consultant

Project Description:
As an experienced Cloud consultant, you will be directly involved with all technical stakeholders to design project architectures while ensuring technical solutions align with our clients' strategic directions. Your main mission will involve defining, designing, and managing the evolution of the IT system architecture, ensuring the overall definition of the technical solution, developing targets for IT system evolution, and defining and maintaining the company's technical architecture repository. You will be responsible for tasks such as participating in defining technical solution architectures, conducting detailed studies following standard norms, deploying solutions, ensuring availability, creating test sets for integration unit tests, identifying and addressing malfunctions, providing level 3 support, and drafting and maintaining usage guides and production documents.

Profile Description:
You are proficient in the following Amazon Web Services (AWS) offerings: EC2, S3, Glue, Lambda, Kinesis, DynamoDB, API Gateway, SageMaker, Fargate, and CloudWatch. You have a solid grasp of CI tools like Github and Jenkins. Proficiency in Python is essential, and knowledge of a JavaScript language (such as Angular, Vue, React, Node.js) would be advantageous. Ideally, you have experience in a Data or Machine Learning project to contribute to AI and ML-focused missions. Your passion and personality are key assets for your growth within a small and enthusiastic team!
""",

"""AWS Engineer - Cloud Management Team

About the Company:
Join our Cloud Management team at Alter Way, located in Montpellier, where we have around thirty team members out of a total of eighty. Our core activity revolves around web hosting and management, both in-house and on various cloud platforms, serving approximately 300 clients across e-commerce, healthcare, startups, media, and industrial sectors. With over 20 years of expertise, Alter Way is consistently ranked among the top high-availability web hosts, providing tailored, high-value services to meet our clients' needs while adhering to energy efficiency standards in server hosting.

Your Future Mission:
As our AWS Engineer, your main responsibilities will include:

Guiding clients in selecting the most suitable platform for their use case.
Advising, challenging, and tailoring our solution to meet their business imperatives (human, technical, and financial).
Implementing our recommendations and supporting teams in their skills development.
Managing migration processes.
Cultivating and training internal teams.
Contributing to the Cloud-DevOps ecosystem through meetups, blogs, evangelization, etc.
In our daily work, we prioritize Linux and open-source technologies, ensuring high availability of web services, and leveraging AWS.
About You:
For this role, we seek an engineer with substantial autonomy in using, implementing, and configuring the following tools:

AWS/Cloud (Professional Certification would be advantageous).
Linux/Nginx/Apache/MySQL/Varnish.
CDN/Cache.
Git.
Terraform.
If you are passionate about new technologies, creative, committed, and possess strong technical convictions, we want to hear from you!
""",

"""Junior DevOps Engineer

About the Company:
Achil is recruiting on behalf of its client, an IT service company based in Bordeaux, seeking a Junior DevOps Engineer. Our client is an IT service provider, passionate about digital solutions, dedicated to turning ideas into reality, and enhancing the daily operations of businesses.

Job Description:
As a Junior DevOps Engineer, you will play a key role in managing our technical infrastructure. Your mission will involve ensuring the reliability and performance of our systems by closely collaborating with our development teams.

Your Responsibilities:

Design and maintain resilient infrastructures on Linux.
Orchestrate service deployments using Docker and Kubernetes.
Automate environment configuration with Puppet.
Create continuous integration and deployment pipelines with Jenkins.
Collaborate with development teams to ensure smooth product delivery.
Profile Description:
What you bring to the table:

Passion for technology and a desire to learn.
Team spirit and ability to work collaboratively.
Practical experience with DevOps tools such as Docker, Kubernetes, Puppet, and Jenkins.
Strong communication skills, in both French and English.
2-3 years of experience (including internship experience).
Driver's license (Permis B).
Available at the earliest convenience.
""",

"""Machine Learning Engineer (Internship)

Job Description:
As part of our development efforts, we are seeking a Machine Learning Engineer. Reporting to the Applied Science department of our R&D department, your main mission will be to participate in the development and deployment of Machine Learning tools to support decision-making throughout our process of creating new varieties.

Your Responsibilities:

Conduct literature reviews to identify the use cases of machine learning tools to address our challenges.
Create pipelines to collect and prepare data from various sources for analysis (data engineering).
Develop tools (Python packages) to share your work across different projects (software engineering).
Evaluate predictive models iteratively to improve their prediction quality and generalization.
Implement a complete MLOps approach, managing the end-to-end lifecycle of models to automate business processes and monitor their effectiveness.
Assist Data Scientists and Analysts in implementing data science algorithms by providing advice to ensure effective scaling and adherence to best practices.
Requirements:

Currently enrolled in the second or final year of an engineering school (or equivalent) in Computer Science / Statistics specializing in Data Science and Machine Learning.
Familiarity with the lifecycle of a data science project and "best practices" of software development (writing modular and documented code, collaboration and versioning practices, unit testing, documentation).
Theoretical and practical knowledge of Machine Learning: Regression, Classification, Computer Vision, Deep Learning.
Practical knowledge of SQL.
Proficiency in Python development using major data analysis packages (pandas, numpy, scikit-learn, tensorflow), visualization/reporting tools (matplotlib, plotly, streamlit), and web API development (flask).
Knowledge of Cloud technologies (AWS) and containerization (Docker).
Creative problem-solving skills, proactive, and excellent interpersonal skills, known for autonomy, reactivity, and organization.
""",

""" 13 AI Generative Engineer Position in Montpellier

Job Description:
Iziwork, the #1 digital temporary agency in France, is seeking an AI Generative Engineer in Montpellier. Apply in seconds and benefit from personalized support from your agency on a daily basis. Ready to shape the future with your creativity and the latest advances in Generative Artificial Intelligence?

About the Mission:
As an AI expert, you will be responsible for the following tasks:

Conducting in-depth research to design and develop advanced ML models, focusing on LLMs.
Exploring new architectures and techniques to enhance model performance.
Fine-tuning and adapting pre-trained LLMs for specific NLP tasks (text generation).
Optimizing their performance to handle large datasets and high-volume real-time inference requirements.
Working closely with multidisciplinary teams to define and implement training, fine-tuning, validation, and evaluation strategies for LLMs.
Ensuring their optimal performance and accuracy.
Experimenting with different architectures, hyperparameters, and training techniques.
Incorporating cutting-edge techniques, tools, and frameworks for LLM research and development.
Introducing multi-objective optimization methodologies to effectively balance model performance.
Collaborating with DataOps to implement and manage data preprocessing pipelines.
Ensuring data quality and consistency for LLM training.
Profile Requirements:

Autonomous and ambitious in your daily work.
Minimum of 2 years of experience in creating, developing, and optimizing large-scale language models, especially transformer-based models.
Advanced mastery of Python and practical experience with deep learning libraries such as PyTorch.
Expertise in natural language processing (NLP) techniques, including word embeddings, attention mechanisms, transformer models, continuous training schedulers, SFT/DPO fine-tuning techniques, and transfer learning.
Experience: Between 24 months and 5 years.
""",

""" Research Engineer in Computer Vision and Machine Learning

Who You Are:
With a higher education background (Bac+5), you specialize in Computer Vision, Computer Science, or Machine Learning and have at least 3 years of research experience. You have significant experience in data classification through Deep Learning, recurrent neural networks, Random Forest, SVM, or similar methods. Proficiency in a machine learning framework like PyTorch, TensorFlow, CNTK, or Scikit-learn is essential. Mastery of Python coding is indispensable. You are rigorous, committed, and possess strong analytical skills. Knowledge in infrared imaging, C++, and GPU would be a plus. Additionally, you have good written comprehension of the English language.

What We Can Achieve Together:
The Elancourt site brings together all the means for the development, integration, and testing of optronic, missile electronic, and intense laser activities for Thales in France. As part of our machine learning activities, we are seeking a research engineer responsible for studying and developing innovative algorithmic solutions for airborne equipment. You will join the Image Processing Service (STI) to develop image and video analysis treatments based on artificial intelligence techniques (machine learning, deep learning, etc.).

Your Main Missions Include:

Contributing to research projects that will shape the future of optronics.
Conducting technological watch, sharing your readings, and participating in conferences.
Proposing and testing promising ideas on demonstrators.
Designing treatment solutions applied to computer vision issues.
Evaluating and optimizing performance.
Participating in the real-time implementation of the solution in an embedded system.
""",

""" Generative AI Engineer Position with Professional Training Opportunity

Job Description:
Are you a job seeker keenly interested in the fields of Data and AI? We offer a permanent contract preceded by an accelerated professional training of 400 hours, within the framework of an Individual Operational Preparation for Employment (POEI), to ensure that you are fully operational and 100% comfortable in the assigned mission. To benefit from the POEI program, you must be registered with France Travail (formerly Pôle Emploi). Conducted by recognized professionals, this training takes place over a period of 12 weeks. Upon completion of the training and within our project teams, you will evolve into a position as a Generative AI Engineer (LLMOPS).

Key Responsibilities:
As a Generative AI Engineer, you will be responsible for proposing the best solutions to the company to optimize their activity, through several main missions:

Having a good approach to NLP.
Mastering Transformers and LLM attention mechanisms.
Managing life cycles and building an LLM App.
Having a deep understanding of Prompt Engineering concepts.
Mastering the complete life cycle management of LLM projects with MLflow and CometLLM.
Using Docker for environment containerization usable via Kubernetes and managing the installation and configuration of Kubeflow for machine learning in Kubernetes.
Using features of Vertex AI/Amazon Bedrock/Mistral... for natural language processing (LLM).
Profile Requirements:
You hold at least a Bachelor's degree +5 and have at least 2 to 3 years of professional experience as a Data Engineer, Data Scientist, or post-doctoral researcher looking for your first permanent contract.

""",


""" 9 Opportunity for Machine Learning Engineer at InstaDeep

Job Description:
Are you a Machine Learning Engineer focused on gathering information and generating knowledge on AI using both theoretical and experimental means? If so, keep reading... As a Machine Learning Engineer at InstaDeep, your goal is to develop and implement novel ideas while building simple and sustainable software solutions. You will report to the Senior Product Lead and may require overseas travel. Key responsibilities include developing prototype applications, providing software design and programming support to research projects, and implementing software libraries.

Responsibilities:

Develop novel algorithms and research ideas in machine learning, deep learning, and reinforcement learning.
Integrate new fundamental research into applied projects, bridging the gap between research and products.
Collaborate with the Engineering team to design and run experiments, implementing and evaluating new algorithms.
Design and implement algorithms to leverage modern hardware and distributed computing systems.
Write and maintain high-quality, modular code with concise documentation and tests.
Report and present experimental results and research findings clearly and efficiently, internally and externally.
Qualifications:

MSc/PhD degree in Computer Science or a related scientific field.
Minimum 1 year of professional experience in AI or similar fields.
Proficiency in C/C++, Python, or similar languages for development and debugging.
Experience with deep learning frameworks like PyTorch, Tensorflow, and/or Keras.
Knowledge of storage systems, distributed systems, HPC, compilers, and/or CUDA programming is advantageous.
Demonstrated research and software engineering experience through internships, open-source contributions, or coding competitions.
Excellent communication and collaboration skills with researchers and developers.
Our Commitment to Our People: [Additional information can be included here]

""",

"""Brand Marketing Manager at Level Infinite

Job Description:
At Level Infinite, we are committed to delivering engaging and original gaming experiences to a worldwide audience, fostering inclusivity, connection, and accessibility. As a Brand Marketing Manager, you will play a pivotal role in developing the brand identity, messaging components, and marketing strategy to drive our overall vision. You'll collaborate closely with the LiveOps team to support promotion plans, analyze market trends, and execute promotional events.

Responsibilities:

Develop brand identity and key messaging components to drive the overall vision and brand marketing strategy.
Collaborate with the LiveOps team to support promotion plans, including KOL/paid media/performance media/community.
Work with other functions such as Studios, process, and financial teams to ensure a solid and consistent launch and long-term operation and marketing.
Track all marketing activity, provide analysis and guidance for improvement, and conduct market research.
Liaise with projects to execute promotional events and handle ad-hoc projects as assigned.
Manage budget and procurement processes.
Requirements:

Degree in marketing, communication, gaming, or related disciplines.
3 years’ experience in marketing, preferably in the gaming/IT/Internet industry.
Well-organized with good communication and presentation skills.
Excellent command of written & spoken English & Mandarin.
Familiarity with digital marketing and traditional marketing tools.
Immediate availability preferred.
Passionate about playing PC, Console, and mobile games.
About Level Infinite:
Level Infinite is a leading publisher and collaborative partner in the gaming industry, delivering breakout hit games like PUBG MOBILE and Goddess of Victory: NIKKE. To learn more about Level Infinite, visit levelinfinite.com and follow us on Twitter, Facebook, Instagram, and YouTube.

""",

"""Senior .NET Developer at ODDO BHF

Job Description:
As a Senior .NET Developer at ODDO BHF, you will be part of the Asset Management IT Department, responsible for monitoring, developing, and optimizing the Information System of the Asset Management Entity within the ODDO BHF Group. Working closely with teams in Paris, Dusseldorf, and Tunis, you will analyze system needs, write clean and testable code, develop technical specifications, and support junior teammates.

Responsibilities:

Analyze system needs and prioritize tasks in coordination with teams in France, Tunisia, and Germany.
Write clean and testable code in .NET, C#, and T-SQL programming languages.
Develop architecture and technical specifications with group architects.
Review and refactor existing program code.
Support junior teammates and document development and operational procedures.
Requirements:

Bachelor's or Master's degree in IT development.
Minimum 3 years of IT development experience in Microsoft Environment (.NET, C#, T-SQL, SSIS).
Ability to think critically and suggest automation processes.
Excellent written and oral communication skills in English and French.
Rigorous with the ability to maintain quality work over time.
High degree of commitment.
Preferred Skills:

Good knowledge of Java programming.
Experience with Jira, Azure DevOps, and Agile methodologies (Scrum).
Knowledge of the German language is a plus.
""",

"""12 AI Specialist at DIGWAY

Job Description:
As an AI Specialist at DIGWAY, you will be responsible for designing, developing, and deploying innovative AI solutions for our client project in the field of virtual reality and sports. Your main responsibilities include:

Analyzing client needs and identifying opportunities for AI application in the fields of virtual reality and sports.
Designing and developing customized AI models to meet project-specific requirements.
Collaborating with development teams to integrate AI solutions into existing applications.
Evaluating and optimizing the performance of AI models using testing and analysis techniques.
Conducting continuous technological watch to stay updated on advancements in the AI and virtual reality fields.
Required Profile:

Significant experience in developing AI applications, preferably in the field of virtual reality or sports.
Mastery of machine learning techniques, including neural networks, supervised and unsupervised learning algorithms.
Strong programming skills, especially in languages like Python, TensorFlow, or PyTorch.
Ability to work in a team and collaborate effectively with clients and other team members.
Passion for technological innovation and interest in AI applications in the sports and virtual reality domain.
""",

"""HR Coordinator

Job Description:
As an HR Coordinator, you will be responsible for various activities related to recruitment and HR management. Your main tasks include:

Recruitment:

Supporting recruitment activities across the designated area: participating in defining needs, preselecting candidates in partnership with Pôle Emploi, and monitoring the recruitment process and contracts.
Ensuring the successful integration of candidates: onboarding, appointment notes, integration sessions.
HR Management:

Participating in the deployment of the professional interview process and ensuring follow-up with managers.
Maintaining the reliability of HRIS data.
Personnel administration:
Monitoring the editing and signing of employment contracts.
Digitizing documents and updating the collaborative payroll database.
Drafting letters for employees: certificates, sponsorship letters, etc.
Training:
Collaborating with the HR and Management Assistant to ensure the smooth running of the training plan for all employees.
Candidate Profile:

Bachelor's degree (Bac+5) in a related field, ideally with some internship experience in HR.
Ability to maintain confidentiality, provide service-oriented support, and enjoy hands-on tasks.
Strong analytical, formalization, structuring, and synthesis skills.
Good listening skills and strong interpersonal qualities.

""",

"""Test Automation Engineer

Description:
As a Test Automation Engineer at DIGWAY, you will be responsible for setting up test processes, tools, and automation for web projects. Your main responsibilities include:

Developing expertise in automation processes, tools, and techniques to enhance overall product quality.
Contributing to test plan creation and execution during testing phases.
Developing automation test scripts.
Analyzing coverage rates.
Staying updated on technological advancements in AI and virtual reality.
Profile:

Bachelor's degree in Computer Science or related field.
Experience with automation tools such as Postman, Selenium, Cypress, or RobotFramework.
Familiarity with QA tools like HP Quality Center, Xray, and Jira.
Passion for staying updated with the latest technologies and proposing innovative solutions.
""",

"""Software Test Engineer (Embedded Systems)

Description:
We are seeking a fresh graduate software engineer to join our team in Tunis. The role involves working with cross-functional teams to develop the test framework for STM32 Cube HAL & examples. Responsibilities include:

Understanding developers' needs and proposing solutions to automate software testing processes.
Designing and implementing an automatic framework for all MCU Embedded Software test activities.
Integrating the automation framework into CI/CD pipelines.
Required Skills:

Proficiency in automation scripting (Python, Shell, etc.).
Knowledge of automation technologies & tools.
Excellent teamwork and communication skills.
Strong problem-solving abilities.

""",

"""Software Tester / QA Engineer

Description:
We are looking for a dynamic Software Tester / QA Engineer to join a software editor team based in Montpellier. Responsibilities include:

Conducting tests to ensure product and service quality.
Performing manual tests to identify and report anomalies.
Implementing automated testing tools to improve testing processes.
Collaborating with developers and technical teams to resolve identified issues.
Profile:

Bachelor's degree or equivalent in Computer Science.
Minimum 2 years of experience as a Software Tester / QA Engineer.
Experience using Postman for testing.
Proficiency in Jenkins for test automation.
""",

"""QA Tester

Description:
As a QA Tester, you will ensure the quality of software and systems developed for the automotive industry. Responsibilities include:

Designing test scenarios and detailed test plans for automotive applications.
Performing manual and automated tests to assess software functionality, performance, and security.
Documenting test results and reporting detected anomalies.
Collaborating closely with developers to understand project functional and technical requirements.
Contributing to continuous improvement of test and development processes.
Profile:

Previous experience as a QA Tester.
Degree in computer science or related field.
Knowledge of quality standards and best testing practices.
Ability to design comprehensive test scenarios and execute tests methodically.
Understanding of embedded software, automotive connectivity, or vehicle management systems is advantageous.
Excellent communication and problem-solving skills.
""",




]

# %%
import re
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Provided JSON-like input
parsed_cv = {
  "data": {
    "name": "Amira Ben Salah",
    "email": "amira.bensalah@datasci.tn",
    "age": None,
    "gender": "Female",
    "years_of_experience": "8.0",
    "linkedin_url": "/in/amira-ben-salah/",
    "current_position": "Senior Data Scientist",
    "country_of_residence": "Tunisia",
    "phone": "+216 55443322",
    "date_of_birth": None,
    "languages": [
      "Arabic        Native",
      "French     Fluent",
      "English      Fluent"
    ],
    "domain": None,
    "skills": [
     {
      "skill_name": "Proficient in Python and R for data analysis and scripting"
     },
     {
      "skill_name": "Expert in applying machine learning techniques, including neural networks, for predictive analytics and problem solving"
     },
     {
      "skill_name": "Skilled in leveraging data visualization tools like Tableau and Power BI to transform complex data sets into actionable insights"
     },
     {
      "skill_name": "Experienced with big data ecosystems, including Hadoop and Spark, for large-scale data processing"
     },
     {
      "skill_name": "Strong statistical analysis skills, proficient in using statistical software to conduct various types of analysis and testing"
     },
     {
      "skill_name": "Advanced data manipulation skills using libraries such as Pandas and NumPy"
     },
     {
      "skill_name": "Deep knowledge of SQL and familiarity with NoSQL databases, including MongoDB"
     },
     {
      "skill_name": "Comprehensive understanding of data warehousing principles, including ETL processes and data modeling"
     },
     {
      "skill_name": "Adept in using AI frameworks like TensorFlow and PyTorch for developing and deploying AI models"
     }
  ],
    "education": [
      {
        "school_name": "MedTech Tunis",
        "degree_name": "Bachelor's Degree in Software Engineering",
        "graduation_date": "2015"
      }
    ],
    "experience": [
      {
        "company_name": "Innovative Tech Solutions",
        "position": "Senior Data Scientist",
        "description": "Led a team to develop machine learning models that increased customer retention by 30%. Spearheaded the integration of AI-driven analytics into the company's main products, significantly enhancing predictive capabilities and operational efficiency. Implemented robust data pipelines using Python and R to streamline data collection and preprocessing.",
        "date": "January 2020 - Present"
      },
      {
        "company_name": "DataWise Analytics",
        "position": "Data Scientist",
        "description": "Developed several forecasting models that reduced financial waste by 25%. Utilized complex statistical analysis to understand customer behaviors and sales patterns. Coordinated with IT and business stakeholders to implement a real-time analytics platform using Spark and Kafka.",
        "date": "March 2017 - December 2019"
      },
      {
        "company_name": "TechStartUp Co.",
        "position": "Junior Data Scientist",
        "description": "Contributed to various data mining projects that supported strategic decision-making. Designed and implemented data visualization dashboards that tracked KPIs and improved report accessibility for non-technical users. Participated in workshops and seminars to continually upgrade technical skills.",
        "date": "June 2015 - February 2017"
      }
    ],
    "certificates": [
      {
        "CertificateName": "Certified Data Scientist",
        "Organization": "Data Science Council of America"
      },
      {
        "CertificateName": "Google Data Analytics Professional Certificate",
        "Organization": "Coursera"
      }
    ],
    "source": "cv",
    "file_name": "CV_Amira_Ben_Salah_Data_Scientist.pdf"
  },
  "is_candidate_exist": True
}

# %%
# !pip install gliner
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 60.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 28.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 22.3 MB/s eta 0:00:00
# ...

# %%
from gliner import GLiNER

# Initialize GLiNER with the desired model version
model = GLiNER.from_pretrained("urchade/gliner_medium-v2.1")

# Define the text data to be analyzed
# Concatenate skills, experience descriptions, and certificate details
skills_text = ' '.join(skill['skill_name'] for skill in parsed_cv['data']['skills'])
experience_text = ' '.join(exp['description'] for exp in parsed_cv['data']['experience'])
certificates_text = ' '.join(cert['CertificateName'] for cert in parsed_cv['data']['certificates'])

full_text = skills_text + " " + experience_text + " " + certificates_text

# Specify the entity types we're interested in, based on GLiNER's capabilities
labels = ["Skill", "Technology", "Programming Language"]

# Perform entity prediction
entities = model.predict_entities(full_text, labels, threshold=0.5)

# Extract and print out the skills
extracted_skills = [entity['text'] for entity in entities if entity['label'] in labels]
print(extracted_skills)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/781M [00:00<?, ?B/s]
# gliner_config.json:   0%|          | 0.00/476 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# ...

# %%
candidate_field = "data science"
extracted_skills = list(filter(lambda x: x != 'R', extracted_skills))
print(extracted_skills)
# Out:
# ['Python', 'Tableau', 'Power BI', 'Hadoop', 'Spark', 'Strong statistical analysis skills', 'Advanced data manipulation skills', 'Pandas', 'SQL', 'NoSQL databases', 'MongoDB', 'TensorFlow', 'Python', 'Spark', 'Kafka']

# %%
info_to_summarize = {
    "years_of_experience": parsed_cv["data"]["years_of_experience"],
    "current_position": parsed_cv["data"]["current_position"],
    "languages": [lang.strip() for lang in parsed_cv["data"]["languages"]],
    "skills": extracted_skills,
    "experience": [exp["description"] for exp in parsed_cv["data"]["experience"]],
    "certificates": [cert["CertificateName"] for cert in parsed_cv["data"]["certificates"]],
    "education": [{
        "degree_name": edu["degree_name"],
        "graduation_date": edu["graduation_date"]
    } for edu in parsed_cv["data"]["education"]] if parsed_cv["data"]["education"] else []
}

print(info_to_summarize)
# Out:
# {'years_of_experience': '8.0', 'current_position': 'Senior Data Scientist', 'languages': ['Arabic        Native', 'French     Fluent', 'English      Fluent'], 'skills': ['Python', 'Tableau', 'Power BI', 'Hadoop', 'Spark', 'Strong statistical analysis skills', 'Advanced data manipulation skills', 'Pandas', 'SQL', 'NoSQL databases', 'MongoDB', 'TensorFlow', 'Python', 'Spark', 'Kafka'], 'experience': ["Led a team to develop machine learning models that increased customer retention by 30%. Spearheaded the integration of AI-driven analytics into the company's main products, significantly enhancing predictive capabilities and operational efficiency. Implemented robust data pipelines using Python and R to streamline data collection and preprocessing.", 'Developed several forecasting models that reduced financial waste by 25%. Utilized complex statistical analysis to understand customer behaviors and sales patterns. Coordinated with IT and business stakeholders to implement a real-time analy
# ...

# %%
candidate_skills = info_to_summarize["skills"]
# Function to match candidate's field and skills with job descriptions
def match_keywords_with_jobs(candidate_field, candidate_skills, jobs):
    matched_jobs = []
    for job in jobs:
        # Check if the candidate's field is mentioned in the job description
        if candidate_field.lower() in job.lower():
            matched_jobs.append((job, "Field Match"))
            continue  # Move to the next job if field matches

        # Check each skill for a match in the job description
        for skill in candidate_skills:
            if skill.lower() in job.lower():
                matched_jobs.append((job, f"Skill Match: {skill}"))
                break  # Only add the job once for the first matching skill

    return matched_jobs

# %%
matched_jobs = match_keywords_with_jobs(candidate_field, info_to_summarize["skills"], jobs)

# Display matched jobs
print("Matched Jobs for this cv:")
for job, reason in matched_jobs:
    job_title = job.split('\n')[0].strip()  # Splitting and stripping outside the f-string
    print(f"- {job_title} ({reason})")
# Out:
# Matched Jobs for this cv:
# - 3 Senior Data Scientist (Field Match)
# - 1 Senior Data Scientist Sigma Software Group (Field Match)
# - 10 ML Engineer / Data Scientist (Field Match)
# - 18   Senior Data Scientist Sky Ledge · Istanbul (Field Match)
# - 19 Senior Data Scientist Wordwall · United Kingdom (Field Match)
# - 14 Data Scientist TriNetX · Freiburg, Baden-Württemberg, Germany (Skill Match: Python)
# - Android Developer (Skill Match: SQL)
# - Software Development Intern (Full Stack) (Skill Match: Python)
# - 2 Data Scientist - Asset Management (Field Match)
# - 4 Machine Learning Engineer (Field Match)
# - Machine Learning Engineer - InstaDeep (Skill Match: Python)
# - Responsibilities: (Skill Match: Python)
# - Operations Apprentice at Cyberwatch, a Framatome Subsidiary (Skill Match: Python)
# - Cybersecurity Intern at CERT-CEA (Skill Match: Python)
# - 5 Data Engineer Position (Skill Match: Python)
# - 6 Senior Data Scientist - Deep Learning Specialist (Field Match)
# ...

# %% [markdown]
# check with TP TN ( accuracy)

# %% [markdown]
# 29 jobs were removed by this filter

# %%
text_block = f"""
Experience: {info_to_summarize["experience"]}
Skills: {info_to_summarize["skills"]}
Certificates: {info_to_summarize["certificates"]}
Education: {info_to_summarize["education"]}
Languages: {info_to_summarize["languages"]}
Current Position: {info_to_summarize["current_position"]}, with {info_to_summarize["years_of_experience"]} years of experience.
"""
print(text_block)
# Out:
# Experience: ["Led a team to develop machine learning models that increased customer retention by 30%. Spearheaded the integration of AI-driven analytics into the company's main products, significantly enhancing predictive capabilities and operational efficiency. Implemented robust data pipelines using Python and R to streamline data collection and preprocessing.", 'Developed several forecasting models that reduced financial waste by 25%. Utilized complex statistical analysis to understand customer behaviors and sales patterns. Coordinated with IT and business stakeholders to implement a real-time analytics platform using Spark and Kafka.', 'Contributed to various data mining projects that supported strategic decision-making. Designed and implemented data visualization dashboards that tracked KPIs and improved report accessibility for non-technical users. Participated in workshops and seminars to continually upgrade technical skills.']
# ...

# %%
# !pip install sentence-transformers numpy
from sentence_transformers import SentenceTransformer
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 3.6 MB/s eta 0:00:00
# ...

# %%
! pip install cohere
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.2/151.2 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 17.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flair 0.13.1 requires urllib3<2.0.0,>=1.0.0, but you have urllib3 2.2.1 which is incompatible.
# ...

# %%
import cohere
# Initialize Cohere client
co = cohere.Client('WpKC0uQXJE03JfJCkC66zIFaPYy6AkLLlH39vZe1')

# %%
import requests

def generate_cohere_embeddings(texts, model_name='embed-english-v3.0', input_type='search_document'):
    url = "https://api.cohere.ai/v1/embed"
    headers = {
        "X-Client-Name": "YourProjectName",
        "Authorization": "Bearer WpKC0uQXJE03JfJCkC66zIFaPYy6AkLLlH39vZe1"
    }
    data = {
        "texts": texts,
        "model": model_name,
        "input_type": input_type
    }
    response = requests.post(url, json=data, headers=headers)
    if response.status_code == 200:
        return response.json()["embeddings"]
    else:
        raise Exception(f"Cohere API request failed with status code {response.status_code} and message: {response.json()['message']}")

# %%
def generate_cohere_embeddings(texts, model_name='embed-english-v3.0', input_type='search_document'):
    # Cohere API call setup
    response = co.embed(
        model=model_name,
        texts=texts,
        input_type=input_type
    )
    return response.embeddings

# %%
# Initialize the models
models = {
    'MiniLM': SentenceTransformer('all-MiniLM-L6-v2'),
    'Cohere': 'cohere'
}

# %%
# Iterate over models and calculate similarity scores
for model_name, model in models.items():
    try:
        if model_name == 'Cohere':
            # Generate Cohere embeddings for text block and matched jobs
            candidate_embedding = generate_cohere_embeddings(list(text_block))
            matched_job_embeddings = generate_cohere_embeddings(matched_jobs)
        else:
            candidate_embedding = model.encode(text_block)
            matched_job_embeddings = model.encode(matched_jobs)

        # Calculate cosine similarity between candidate and matched job embeddings
        cos_sim = cosine_similarity([candidate_embedding], matched_job_embeddings)[0]
        # Convert cosine similarities to percentages
        similarity_percentages = cos_sim * 100
        # Sort the job postings by similarity
        ranked_job_indices = np.argsort(similarity_percentages)[::-1]

        # Display the ranked job postings with similarity scores
        print(f"Results with {model_name}:")
        for index in ranked_job_indices:
            print(f"- {matched_jobs[index]} \nSimilarity Score: {similarity_percentages[index]:.2f}%")
        print("\n")

    except Exception as e:
        print(f"An error occurred with {model_name}: {str(e)}")
# Out:
# Results with MiniLM:
# ...
